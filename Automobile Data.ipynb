# %%
#Import the packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv("c:\\Users\\Sagar\\Downloads\\AutoData (1).csv")
df
# Out:
#      symboling                      make fueltype aspiration doornumber  \
# 0            3        alfa-romero giulia      gas        std        two
# 1            3       alfa-romero stelvio      gas        std        two
# 2            1  alfa-romero Quadrifoglio      gas        std        two
# 3            2               audi 100 ls      gas        std       four
# 4            2                audi 100ls      gas        std       four
# ..         ...                       ...      ...        ...        ...
# 200         -1           volvo 145e (sw)      gas        std       four
# 201         -1               volvo 144ea      gas      turbo       four
# 202         -1               volvo 244dl      gas        std       four
# 203         -1                 volvo 246   diesel      turbo       four
# 204         -1               volvo 264gl      gas      turbo       four
#
#          carbody drivewheel enginelocation  wheelbase  carlength  ...  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 25 columns):
# symboling           205 non-null int64
# make                205 non-null object
# fueltype            205 non-null object
# aspiration          205 non-null object
# doornumber          205 non-null object
# carbody             205 non-null object
# drivewheel          205 non-null object
# enginelocation      205 non-null object
# wheelbase           205 non-null float64
# carlength           205 non-null float64
# carwidth            205 non-null float64
# carheight           205 non-null float64
# curbweight          205 non-null int64
# enginetype          205 non-null object
# cylindernumber      205 non-null object
# enginesize          205 non-null int64
# fuelsystem          205 non-null object
# boreratio           205 non-null float64
# stroke              205 non-null float64
# compressionratio    205 non-null float64
# horsepower          205 non-null int64
# ...

# %%
df.isnull().sum()
# Out:
# symboling           0
# make                0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
df.describe()
# Out:
#         symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000
# mean     0.834146   98.756585  174.049268   65.907805   53.724878
# std      1.245307    6.021776   12.337289    2.145204    2.443522
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  166.300000   64.100000   52.000000
# 50%      1.000000   97.000000  173.200000   65.500000   54.100000
# 75%      2.000000  102.400000  183.100000   66.900000   55.500000
# max      3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# std     520.680204   41.642693    0.270844    0.313597          3.972040
# min    1488.000000   61.000000    2.540000    2.070000          7.000000
# ...

# %%
df.describe(include=['object'])
# Out:
#                  make fueltype aspiration doornumber carbody drivewheel  \
# count             205      205        205        205     205        205
# unique            147        2          2          2       5          3
# top     toyota corona      gas        std       four   sedan        fwd
# freq                6      185        168        115      96        120
#
#        enginelocation enginetype cylindernumber fuelsystem
# count             205        205            205        205
# unique              2          7              7          8
# top             front        ohc           four       mpfi
# freq              202        148            159         94

# %% [markdown]
# #### Univariate Analysis

# %%
plt.boxplot(df['price'])
plt.xlabel('Price',fontsize=15)
plt.show()

# %%
df['make'].value_counts(normalize=True)
# Out:
# toyota corona          0.029268
# peugeot 504            0.029268
# toyota corolla         0.029268
# subaru dl              0.019512
# mitsubishi g4          0.014634
#                          ...
# isuzu D-Max V-Cross    0.004878
# nissan kicks           0.004878
# toyota celica gt       0.004878
# bmw x1                 0.004878
# buick skyhawk          0.004878
# Name: make, Length: 147, dtype: float64

# %%
df['fueltype'].value_counts(normalize=True)
# Out:
# gas       0.902439
# diesel    0.097561
# Name: fueltype, dtype: float64

# %%
df['carbody'].value_counts(normalize=True)
# Out:
# sedan          0.468293
# hatchback      0.341463
# wagon          0.121951
# hardtop        0.039024
# convertible    0.029268
# Name: carbody, dtype: float64

# %%
df['doornumber'].value_counts(normalize=True)
# Out:
# four    0.560976
# two     0.439024
# Name: doornumber, dtype: float64

# %%
df['aspiration'].value_counts(normalize=True)
# Out:
# std      0.819512
# turbo    0.180488
# Name: aspiration, dtype: float64

# %%
df['enginelocation'].value_counts(normalize=True)
# Out:
# front    0.985366
# rear     0.014634
# Name: enginelocation, dtype: float64

# %%
df['drivewheel'].value_counts(normalize=True)
# Out:
# fwd    0.585366
# rwd    0.370732
# 4wd    0.043902
# Name: drivewheel, dtype: float64

# %%
df['fuelsystem'].value_counts(normalize=True)
# Out:
# mpfi    0.458537
# 2bbl    0.321951
# idi     0.097561
# 1bbl    0.053659
# spdi    0.043902
# 4bbl    0.014634
# mfi     0.004878
# spfi    0.004878
# Name: fuelsystem, dtype: float64

# %%
df['cylindernumber'].value_counts(normalize=True)
# Out:
# four      0.775610
# six       0.117073
# five      0.053659
# eight     0.024390
# two       0.019512
# twelve    0.004878
# three     0.004878
# Name: cylindernumber, dtype: float64

# %% [markdown]
# #### Multivariate Analysis

# %%
df.groupby(['fueltype'])['price'].mean()
# Out:
# fueltype
# diesel    15838.1500
# gas       12999.7982
# Name: price, dtype: float64

# %%
df.groupby(['aspiration'])['price'].mean()
# Out:
# aspiration
# std      12611.270833
# turbo    16298.166676
# Name: price, dtype: float64

# %%
df.groupby(['carbody'])['price'].mean()
# Out:
# carbody
# convertible    21890.500000
# hardtop        22208.500000
# hatchback      10376.652386
# sedan          14344.270833
# wagon          12371.960000
# Name: price, dtype: float64

# %%
df.groupby(['drivewheel'])['price'].mean()
# Out:
# drivewheel
# 4wd    11087.463000
# fwd     9239.308333
# rwd    19910.809211
# Name: price, dtype: float64

# %%
df.groupby(['doornumber'])['price'].mean()
# Out:
# doornumber
# four    13501.152174
# two     12989.924078
# Name: price, dtype: float64

# %%
df.groupby(['fuelsystem'])['price'].mean()
# Out:
# fuelsystem
# 1bbl     7555.545455
# 2bbl     7478.151515
# 4bbl    12145.000000
# idi     15838.150000
# mfi     12964.000000
# mpfi    17754.602840
# spdi    10990.444444
# spfi    11048.000000
# Name: price, dtype: float64

# %%
df.groupby(['cylindernumber'])['price'].mean()
# Out:
# cylindernumber
# eight     37400.100000
# five      21630.469727
# four      10285.754717
# six       23671.833333
# three      5151.000000
# twelve    36000.000000
# two       13020.000000
# Name: price, dtype: float64

# %%
df.groupby(['enginelocation'])['price'].mean()
# Out:
# enginelocation
# front    12961.097361
# rear     34528.000000
# Name: price, dtype: float64

# %%
sns.pairplot(df,x_vars=['curbweight','enginesize','boreratio','stroke','compressionratio'],y_vars='price',markers='+',diag_kind='kde')
plt.show()

# %%
sns.pairplot(df,x_vars=['symboling','wheelbase','carlength','carwidth','carheight'],y_vars='price',markers='+',diag_kind='kde')
plt.show()

# %%
sns.pairplot(df,x_vars=['horsepower','peakrpm','citympg','highwaympg'],y_vars='price',markers='+',diag_kind='kde')
plt.show()

# %% [markdown]
# #### Label Encoding Categorical Variables

# %%
df1=df.copy()

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
df1['symboling']=le.fit_transform(df['symboling'])
df1['symboling'].unique()
# Out:
# array([5, 3, 4, 2, 1, 0], dtype=int64)

# %%
df1['make']=le.fit_transform(df['make'])
df1['make'].unique()
# Out:
# array([  2,   3,   1,   4,   5,   9,   7,   6,   8,  10,  11,  12,  15,
#         13,  14,  24,  25,  26,  35,  27,  32,  34,  29,  28,  30,  33,
#         31,  39,  43,  37,  38,  42,  36,  41,  44,  40,  47,  45,  46,
#         49,  48,  50,  52,  51,  61,  59,  58,  53,  54,  60,  55,  57,
#         56,  19,  17,  16,  22,  20,  23,  18,  21,  62,  65,  64,  68,
#         63,  66,  67,  69,   0,  73,  81,  76,  83,  77,  74,  78,  70,
#         79,  71,  72,  80,  82,  75,  85,  84,  86,  88,  87,  92,  89,
#         93,  91,  94,  90,  98,  95,  97,  96,  99, 100, 101, 103, 102,
#        104, 107, 106, 105, 108, 109, 110, 111, 123, 120, 116, 121, 117,
#        112, 125, 115, 118, 114, 119, 122, 126, 127, 124, 113, 128, 129,
#        130, 133, 137, 131, 136, 132, 145, 146, 134, 135, 139, 138, 140,
#        141, 143, 144, 142], dtype=int64)

# %%
df1['fueltype']=le.fit_transform(df['fueltype'])
df1['fueltype'].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
df1['aspiration']=le.fit_transform(df['aspiration'])
df1['aspiration'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
df1['doornumber']=le.fit_transform(df['doornumber'])
df1['doornumber'].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
df1['carbody']=le.fit_transform(df['carbody'])
df1['carbody'].unique()
# Out:
# array([0, 2, 3, 4, 1], dtype=int64)

# %%
df1['drivewheel']=le.fit_transform(df['drivewheel'])
df1['drivewheel'].unique()
# Out:
# array([2, 1, 0], dtype=int64)

# %%
df1['enginelocation']=le.fit_transform(df['enginelocation'])
df1['enginelocation'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
df1['enginetype']=le.fit_transform(df['enginetype'])
df1['enginetype'].unique()
# Out:
# array([0, 5, 3, 2, 6, 4, 1], dtype=int64)

# %%
df1['cylindernumber']=le.fit_transform(df['cylindernumber'])
df1['cylindernumber'].unique()
# Out:
# array([2, 3, 1, 4, 5, 6, 0], dtype=int64)

# %%
df1['fuelsystem']=le.fit_transform(df['fuelsystem'])
df1['fuelsystem'].unique()
# Out:
# array([5, 1, 4, 0, 7, 2, 3, 6], dtype=int64)

# %%
df1
# Out:
#      symboling  make  fueltype  aspiration  doornumber  carbody  drivewheel  \
# 0            5     2         1           0           1        0           2
# 1            5     3         1           0           1        0           2
# 2            3     1         1           0           1        2           2
# 3            4     4         1           0           0        3           1
# 4            4     5         1           0           0        3           0
# ..         ...   ...       ...         ...         ...      ...         ...
# 200          1   139         1           0           0        3           2
# 201          1   138         1           1           0        3           2
# 202          1   140         1           0           0        3           2
# 203          1   142         0           1           0        3           2
# 204          1   143         1           1           0        3           2
#
# ...

# %% [markdown]
# #### Correlation and Heatmap

# %%
hm = df1.corr()
hm
# Out:
#                   symboling      make  fueltype  aspiration  doornumber  \
# symboling          1.000000 -0.107095  0.194311   -0.059866    0.664073
# make              -0.107095  1.000000 -0.069435    0.019914   -0.171745
# fueltype           0.194311 -0.069435  1.000000   -0.401397    0.191491
# aspiration        -0.059866  0.019914 -0.401397    1.000000   -0.031792
# doornumber         0.664073 -0.171745  0.191491   -0.031792    1.000000
# carbody           -0.596135  0.099691 -0.147853    0.063028   -0.680358
# drivewheel        -0.041671 -0.016129 -0.132257    0.066465    0.098954
# enginelocation     0.212471  0.055968  0.040070   -0.057191    0.137757
# wheelbase         -0.531954  0.014550 -0.308346    0.257611   -0.447357
# carlength         -0.357612  0.053016 -0.212679    0.234539   -0.398568
# carwidth          -0.232919 -0.075349 -0.233880    0.300567   -0.207168
# carheight         -0.541038  0.201900 -0.284631    0.087311   -0.552208
# ...

# %%
plt.figure(figsize=(20,20))
sns.heatmap(hm,annot=True,cmap='Reds')
plt.show()

# %%
cor = df.corr()
cor
# Out:
#                   symboling  wheelbase  carlength  carwidth  carheight  \
# symboling          1.000000  -0.531954  -0.357612 -0.232919  -0.541038
# wheelbase         -0.531954   1.000000   0.874587  0.795144   0.589435
# carlength         -0.357612   0.874587   1.000000  0.841118   0.491029
# carwidth          -0.232919   0.795144   0.841118  1.000000   0.279210
# carheight         -0.541038   0.589435   0.491029  0.279210   1.000000
# curbweight        -0.227691   0.776386   0.877728  0.867032   0.295572
# enginesize        -0.105790   0.569329   0.683360  0.735433   0.067149
# boreratio         -0.130051   0.488750   0.606454  0.559150   0.171071
# stroke            -0.008735   0.160959   0.129533  0.182942  -0.055307
# compressionratio  -0.178515   0.249786   0.158414  0.181129   0.261214
# horsepower         0.070873   0.353294   0.552623  0.640732  -0.108802
# peakrpm            0.273606  -0.360469  -0.287242 -0.220012  -0.320411
# ...

# %%
sns.jointplot('horsepower','price',data=df,kind='reg')
plt.show()

# %%
sns.jointplot('enginesize','price',data=df,kind='reg')
plt.show()

# %%
sns.jointplot('curbweight','price',data=df,kind='reg')
plt.show()

# %% [markdown]
# From the above EDA i.e. Heat map, Pair plot and Joint plot we ca conclude that horsepower, curbweight and enginesize are more correlated with price. So let's perform simple linear regression (SLR) using enginesize as feature variable. Since it seems more correlated with price.

# %% [markdown]
# #### Simple Linear Regression

# %%
X = df1[['enginesize']]
y = df1['price']

# %% [markdown]
# #### Train_Test_Split

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,train_size=0.7,random_state=42)

# %%
X_train.shape, X_test.shape
# Out:
# ((143, 1), (62, 1))

# %% [markdown]
# #### Linear Regression Model using SciKit Learn

# %%
from sklearn.linear_model import LinearRegression

# %%
mod = LinearRegression()

# %%
mod.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
mod.intercept_
# Out:
# -7646.435077807868

# %%
mod.coef_
# Out:
# array([165.76866245])

# %% [markdown]
# Linear Regression equation becomes,
#
# y = c+mX
#
# price = -7646.4350+165.7686*enginesize

# %%
from sklearn.metrics import r2_score

# %%
y_train_pred = mod.predict(X_train)

# %%
r2_score(y_train,y_train_pred)
# Out:
# 0.7686929078033782

# %% [markdown]
# #### Multi Linear Regression Model

# %%
X = df1.drop(['price'],axis=1)
X
# Out:
#      symboling  make  fueltype  aspiration  doornumber  carbody  drivewheel  \
# 0            5     2         1           0           1        0           2
# 1            5     3         1           0           1        0           2
# 2            3     1         1           0           1        2           2
# 3            4     4         1           0           0        3           1
# 4            4     5         1           0           0        3           0
# ..         ...   ...       ...         ...         ...      ...         ...
# 200          1   139         1           0           0        3           2
# 201          1   138         1           1           0        3           2
# 202          1   140         1           0           0        3           2
# 203          1   142         0           1           0        3           2
# 204          1   143         1           1           0        3           2
#
# ...

# %%
y=df1[['price']]
y
# Out:
#        price
# 0    13495.0
# 1    16500.0
# 2    16500.0
# 3    13950.0
# 4    17450.0
# ..       ...
# 200  16845.0
# 201  19045.0
# 202  21485.0
# 203  22470.0
# 204  22625.0
#
# [205 rows x 1 columns]

# %%
df_train,df_test = train_test_split(df1,train_size=0.7,random_state=42)

# %%
df_train.shape
# Out:
# (143, 25)

# %%
df_test.shape
# Out:
# (62, 25)

# %%
y_train = df_train[['price']]
X_train = df_train
y_test = df_test[['price']]
X_test = df_test

# %% [markdown]
# #### Training Model

# %%
from sklearn.linear_model import LinearRegression

# %%
mod1 = LinearRegression()

# %%
mod1.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
X_train.columns
# Out:
# Index(['symboling', 'make', 'fueltype', 'aspiration', 'doornumber', 'carbody',
#        'drivewheel', 'enginelocation', 'wheelbase', 'carlength', 'carwidth',
#        'carheight', 'curbweight', 'enginetype', 'cylindernumber', 'enginesize',
#        'fuelsystem', 'boreratio', 'stroke', 'compressionratio', 'horsepower',
#        'peakrpm', 'citympg', 'highwaympg', 'price'],
#       dtype='object')

# %%
y_train_pred = mod1.predict(X_train)

# %%
r2_score(y_train,y_train_pred)
# Out:
# 1.0

# %% [markdown]
# #### Recursive Feature Elimination (RFE)

# %%
from sklearn.feature_selection import RFE

# %%
mod2 = LinearRegression()

# %%
rfe_selector = RFE(mod2,10)

# %% [markdown]
# #### Fitting on the train set

# %%
rfe_selector.fit(X_train,y_train)
# Out:
# C:\Users\Sagar\Anaconda3\lib\site-packages\sklearn\utils\validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# RFE(estimator=LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#                                normalize=False),
#     n_features_to_select=10, step=1, verbose=0)

# %%
rfe_selector.support_
# Out:
# array([ True, False,  True,  True,  True,  True,  True,  True, False,
#        False, False, False, False, False, False, False, False,  True,
#        False,  True, False, False, False, False,  True])

# %%
rfe_selector.ranking_
# Out:
# array([ 1, 10,  1,  1,  1,  1,  1,  1,  7,  9,  2,  6, 15,  8,  4, 11,  5,
#         1,  3,  1, 12, 16, 13, 14,  1])

# %%
cols_keep = X_train.columns[rfe_selector.support_]
cols_keep
# Out:
# Index(['symboling', 'fueltype', 'aspiration', 'doornumber', 'carbody',
#        'drivewheel', 'enginelocation', 'boreratio', 'compressionratio',
#        'price'],
#       dtype='object')

# %%
lr2=LinearRegression()

# %%
lr2.fit(X_train[cols_keep],y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_train_pred = lr2.predict(X_train[cols_keep])

# %%
r2_score(y_train,y_train_pred)
# Out:
# 1.0

# %% [markdown]
# #### Statsmodels

# %%
import statsmodels.api as sm

# %%
X_train
# Out:
#      symboling  make  fueltype  aspiration  doornumber  carbody  drivewheel  \
# 177          1   125         1           0           0        2           1
# 75           3    62         1           1           1        2           2
# 174          1   113         0           1           0        3           1
# 31           4    43         1           0           1        2           1
# 12           2    11         1           0           1        3           2
# ..         ...   ...       ...         ...         ...      ...         ...
# 106          3    70         1           0           1        2           2
# 14           3    15         1           0           0        3           2
# 92           3    76         1           0           0        3           1
# 179          5   120         1           0           1        2           2
# 102          2    72         1           0           0        4           1
#
# ...

# %% [markdown]
# Add intercept manually fot statsmodel to work

# %%
X_train_sm = sm.add_constant(X_train[cols_keep])
X_train_sm
# Out:
# C:\Users\Sagar\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
#      const  symboling  fueltype  aspiration  doornumber  carbody  drivewheel  \
# 177    1.0          1         1           0           0        2           1
# 75     1.0          3         1           1           1        2           2
# 174    1.0          1         0           1           0        3           1
# 31     1.0          4         1           0           1        2           1
# 12     1.0          2         1           0           1        3           2
# ..     ...        ...       ...         ...         ...      ...         ...
# 106    1.0          3         1           0           1        2           2
# 14     1.0          3         1           0           0        3           2
# ...

# %%
lr = sm.OLS(y_train,X_train_sm).fit()

# %%
lr.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 9.674e+30
# Date:                Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                        22:49:01   Log-Likelihood:                 3432.2
# No. Observations:                 143   AIC:                            -6842.
# Df Residuals:                     132   BIC:                            -6810.
# Df Model:                          10
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# ...

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
vif=pd.DataFrame()
vif['Features']=X_train.columns
vif['VIF']=[variance_inflation_factor(X_train.values, i) for i in range(X_train.shape[1])]
vif['VIF']=round(vif['VIF'],2)
vif = vif.sort_values(by='VIF',ascending = False)
vif
# Out:
#             Features      VIF
# 10          carwidth  5893.28
# 8          wheelbase  3242.64
# 9          carlength  2434.11
# 11         carheight  1216.58
# 2           fueltype   889.65
# 19  compressionratio   604.22
# 22           citympg   583.56
# 23        highwaympg   572.34
# 12        curbweight   459.46
# 17         boreratio   330.33
# 21           peakrpm   318.35
# 18            stroke   182.80
# 15        enginesize   148.28
# 20        horsepower   104.96
# 24             price    39.26
# 5            carbody    32.04
# 6         drivewheel    20.01
# 0          symboling    19.46
# 14    cylindernumber    18.70
# 13        enginetype    12.39
# 16        fuelsystem    10.08
# 1               make     7.14
# 4         doornumber     5.88
# 3         aspiration     3.34
# 7     enginelocation     1.87

# %% [markdown]
# As clearly visible from VIF and P value,since RFE doesn't give Business sense, we drop that model and go manually using statsmodel.

# %%
X_train1_sm=sm.add_constant(X_train)
X_train1_sm
# Out:
#      const  symboling  make  fueltype  aspiration  doornumber  carbody  \
# 177    1.0          1   125         1           0           0        2
# 75     1.0          3    62         1           1           1        2
# 174    1.0          1   113         0           1           0        3
# 31     1.0          4    43         1           0           1        2
# 12     1.0          2    11         1           0           1        3
# ..     ...        ...   ...       ...         ...         ...      ...
# 106    1.0          3    70         1           0           1        2
# 14     1.0          3    15         1           0           0        3
# 92     1.0          3    76         1           0           0        3
# 179    1.0          5   120         1           0           1        2
# 102    1.0          2    72         1           0           0        4
#
#      drivewheel  enginelocation  wheelbase  ...  enginesize  fuelsystem  \
# ...

# %%
lr1=sm.OLS(y_train,X_train_sm).fit()

# %%
lr1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 9.674e+30
# Date:                Wed, 15 Apr 2020   Prob (F-statistic):               0.00
# Time:                        22:49:02   Log-Likelihood:                 3432.2
# No. Observations:                 143   AIC:                            -6842.
# Df Residuals:                     132   BIC:                            -6810.
# Df Model:                          10
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# ...

# %%
y_train=df_train[['price']]
X_train=df_train[['enginesize','curbweight','horsepower']]
y_test=df_test[['price']]
X_test=df_test[['enginesize','curbweight','horsepower']]

# %%
mod3=LinearRegression()

# %%
mod3.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_train_pred = mod3.predict(X_train)

# %%
r2_score(y_train,y_train_pred)
# Out:
# 0.8268058355162812
