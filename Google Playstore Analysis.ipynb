# %%
#Import the packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv("c:\\Users\\Sagar\\Downloads\\playstore-analysis (2) (1) (1).csv")
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df.info()
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
# App               10841 non-null object
# Category          10841 non-null object
# Rating            9367 non-null float64
# Reviews           10841 non-null object
# Size              10841 non-null float64
# Installs          10841 non-null object
# Type              10840 non-null object
# Price             10841 non-null object
# Content Rating    10840 non-null object
# Genres            10841 non-null object
# Last Updated      10841 non-null object
# Current Ver       10833 non-null object
# Android Ver       10838 non-null object
# dtypes: float64(2), object(11)
# memory usage: 1.1+ MB
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# ...

# %%
print("Missing value in playstore is {}",format(df.isnull().sum()))
# Out:
# Missing value in playstore is {} App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
df.shape
# Out:
# (10841, 13)

# %%
df['Rating'].unique()
# Out:
# array([ 4.1,  3.9,  4.7,  4.5,  4.3,  4.4,  3.8,  4.2,  4.6,  3.2,  4. ,
#         nan,  4.8,  4.9,  3.6,  3.7,  3.3,  3.4,  3.5,  3.1,  5. ,  2.6,
#         3. ,  1.9,  2.5,  2.8,  2.7,  1. ,  2.9,  2.3,  2.2,  1.7,  2. ,
#         1.8,  2.4,  1.6,  2.1,  1.4,  1.5,  1.2, 19. ])

# %%
df=df.dropna(subset=['Rating'])
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10834                                      FR Calculator               FAMILY
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df['Category'].unique()
# Out:
# array(['ART_AND_DESIGN', 'AUTO_AND_VEHICLES', 'BEAUTY',
#        'BOOKS_AND_REFERENCE', 'BUSINESS', 'COMICS', 'COMMUNICATION',
#        'DATING', 'EDUCATION', 'ENTERTAINMENT', 'EVENTS', 'FINANCE',
#        'FOOD_AND_DRINK', 'HEALTH_AND_FITNESS', 'HOUSE_AND_HOME',
#        'LIBRARIES_AND_DEMO', 'LIFESTYLE', 'GAME', 'FAMILY', 'MEDICAL',
#        'SOCIAL', 'SHOPPING', 'PHOTOGRAPHY', 'SPORTS', 'TRAVEL_AND_LOCAL',
#        'TOOLS', 'PERSONALIZATION', 'PRODUCTIVITY', 'PARENTING', 'WEATHER',
#        'VIDEO_PLAYERS', 'NEWS_AND_MAGAZINES', 'MAPS_AND_NAVIGATION',
#        '1.9'], dtype=object)

# %%
df[df['Category']=='1.9']
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#                Size Installs Type     Price Content Rating             Genres  \
# 10472  21516.529524     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %%
df=df.drop([10472])
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10834                                      FR Calculator               FAMILY
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
#Mode value of all the data
mode=df.mode()
mode
# Out:
#       App Category  Rating Reviews          Size    Installs  Type Price  \
# 0  ROBLOX   FAMILY     4.4       2  21516.529524  1,000,000+  Free     0
#
#   Content Rating Genres    Last Updated         Current Ver Android Ver
# 0       Everyone  Tools  August 3, 2018  Varies with device  4.1 and up

# %%
df=df.fillna(df['Android Ver'].mode()[0])
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10834                                      FR Calculator               FAMILY
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
#Mode value is added to the first two empty android ver
df.loc[[4453,4490]]
# Out:
#                          App         Category  Rating Reviews     Size  \
# 4453  [substratum] Vacuum: P  PERSONALIZATION     4.4     230  11000.0
# 4490    Pi Dark [substratum]  PERSONALIZATION     4.5     189   2100.0
#
#      Installs  Type  Price Content Rating           Genres    Last Updated  \
# 4453   1,000+  Paid  $1.49       Everyone  Personalization   July 20, 2018
# 4490  10,000+  Free      0       Everyone  Personalization  March 27, 2018
#
#      Current Ver Android Ver
# 4453         4.4  4.1 and up
# 4490         1.1  4.1 and up

# %%
df=df.fillna(df['Current Ver'].mode()[0])
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10834                                      FR Calculator               FAMILY
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df['Reviews']=df['Reviews'].astype(int)

# %%
df['Price']=df['Price'].str.replace(',','')
df['Price']=df['Price'].str.replace('$','')
df['Price']
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 10834    0
# 10836    0
# 10837    0
# 10839    0
# 10840    0
# Name: Price, Length: 9366, dtype: object

# %%
df['Price']=df['Price'].astype(float)

# %%
df['Installs']=df['Installs'].str.replace(',','')
df['Installs']=df['Installs'].str.replace('+','')
df['Installs']
# Out:
# 0           10000
# 1          500000
# 2         5000000
# 3        50000000
# 4          100000
#            ...
# 10834         500
# 10836        5000
# 10837         100
# 10839        1000
# 10840    10000000
# Name: Installs, Length: 9366, dtype: object

# %%
df['Installs']=df['Installs'].astype(int)

# %%
df.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews             int32
# Size              float64
# Installs            int32
# Type               object
# Price             float64
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
df['Rating'].unique()
# Out:
# array([4.1, 3.9, 4.7, 4.5, 4.3, 4.4, 3.8, 4.2, 4.6, 3.2, 4. , 4.8, 4.9,
#        3.6, 3.7, 3.3, 3.4, 3.5, 3.1, 5. , 2.6, 3. , 1.9, 2.5, 2.8, 2.7,
#        1. , 2.9, 2.3, 2.2, 1.7, 2. , 1.8, 2.4, 1.6, 2.1, 1.4, 1.5, 1.2])

# %%
#Average rating is between 1 and 5
df['Rating'].mode()
# Out:
# 0    4.4
# dtype: float64

# %%
df=df[df['Reviews']<df['Installs']]
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10834                                      FR Calculator               FAMILY
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
plt.boxplot(df['Price'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x957d3dc848>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x957d3dce88>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x957d3cdfc8>],
#  'medians': [<matplotlib.lines.Line2D at 0x957d3e9dc8>],
#  'fliers': [<matplotlib.lines.Line2D at 0x957d3e9ec8>],
#  'means': []}

# %%
#Limiting data records with price < $30
df = df[df['Price']<30]
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10834                                      FR Calculator               FAMILY
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
plt.boxplot(df['Price'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x957d6a0588>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x957d6a0e08>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x957d69bb08>],
#  'medians': [<matplotlib.lines.Line2D at 0x957d6a5d48>],
#  'fliers': [<matplotlib.lines.Line2D at 0x957d6a9bc8>],
#  'means': []}

# %%
plt.boxplot(df['Reviews'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x957d710908>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x957d7158c8>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x957d70ae88>],
#  'medians': [<matplotlib.lines.Line2D at 0x957d715fc8>],
#  'fliers': [<matplotlib.lines.Line2D at 0x957d718fc8>],
#  'means': []}

# %%
df=df[df['Reviews']<1000000]
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10834                                      FR Calculator               FAMILY
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
plt.boxplot(df['Reviews'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x957d785ec8>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x957d788e88>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x957d73b348>],
#  'medians': [<matplotlib.lines.Line2D at 0x957d78efc8>],
#  'fliers': [<matplotlib.lines.Line2D at 0x957d78ef48>],
#  'means': []}

# %%
#Basically the 95th percentile says that 95% of the time, the usage is below this amount.
#For example the highest income value is 400,000 but 95th percentile is 20,000 only. That means 95% of the valuesare less than 20,000.
df['Installs'].max()
# Out:
# 1000000000

# %%
#Dropping records having more than 95th percentile
df=df[df['Installs']<=50000000]
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10834                                      FR Calculator               FAMILY
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
#The implication on this analysis is shown by seaborn boxplot 
#From rating 1.0 to 3.3 are the outliers
#IQR is from rating 4.0 to 4.5
#Q1(25th percentile) rating is 4.0, Q2(75th percentile) rating is 4.5, Median rating is 4.3
#Minimum(Q1-1.5*IQR) rating is 3.3, Maximum(Q3+1.5*IQR) rating is 5.0
sns.boxplot(df['Rating'])

# %%
#More skewed towards higher/lower values is shown in violin plot
plt.violinplot(df['Rating'])
plt.title("Rating Violin Plot")
plt.ylabel("Rating Values ")
# Out:
# Text(0, 0.5, 'Rating Values ')

# %%
#Below histogram shows count for particular range of rating
#3620 Apps have rating between 4.2 to 4.6, more number of app have rating in this range 
plt.hist(df['Rating'].sort_index())
# Out:
# (array([  17.,   18.,   41.,   74.,  136.,  446.,  865., 1619., 3620.,
#         1735.]),
#  array([1. , 1.4, 1.8, 2.2, 2.6, 3. , 3.4, 3.8, 4.2, 4.6, 5. ]),
#  <a list of 10 Patch objects>)

# %%
from matplotlib.pyplot import figure
plt.figure(figsize=(10,7))
sns.countplot(df['Content Rating'])

# %%
df['Content Rating'].value_counts()
# Out:
# Everyone           6896
# Teen                918
# Mature 17+          417
# Everyone 10+        336
# Adults only 18+       3
# Unrated               1
# Name: Content Rating, dtype: int64

# %%
#As Adults only 18+ and Unrated has very low value count i.e. 3 and 1 .So we can drop these two as there won't be much inpact on the data analysis.

# %%
df[(df['Content Rating'] == 'Adults only 18+')]['App']
# Out:
# 298     Manga Master - Best manga & comic reader
# 3043           DraftKings - Daily Fantasy Sports
# 6424                                 Manga Books
# Name: App, dtype: object

# %%
df[(df['Content Rating']=='Unrated')]['App']
# Out:
# 8266    DC Universe Online Map
# Name: App, dtype: object

# %%
df.loc[[298,3043,6424,8266]]
# Out:
#                                            App Category  Rating  Reviews  \
# 298   Manga Master - Best manga & comic reader   COMICS     4.6    24005
# 3043         DraftKings - Daily Fantasy Sports   SPORTS     4.5    50017
# 6424                               Manga Books   COMICS     3.8     7326
# 8266                    DC Universe Online Map    TOOLS     4.1     1186
#
#               Size  Installs  Type  Price   Content Rating  Genres  \
# 298    4900.000000    500000  Free    0.0  Adults only 18+  Comics
# 3043  41000.000000   1000000  Free    0.0  Adults only 18+  Sports
# 6424  21516.529524    500000  Free    0.0  Adults only 18+  Comics
# 8266   6400.000000     50000  Free    0.0          Unrated   Tools
#
#            Last Updated         Current Ver         Android Ver
# 298        July 4, 2018             1.1.7.0          4.1 and up
# 3043      July 24, 2018            3.21.324          4.4 and up
# 6424     August 3, 2018  Varies with device  Varies with device
# ...

# %%
df=df.drop([298,3043,6424,8266])
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10834                                      FR Calculator               FAMILY
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
sns.jointplot(x='Size',y='Rating',data=df,kind='kde',space=0,color='g')

# %% [raw]
# In the above joint plot, I can see that there are more numbers of apps in playstore from size ranging from 20,000 to 25,000 and app rating from 4.1 to 4.6 .
# The second highest numbers apps can be seen from size ranging from 0 to 8,000 and app rating from 4.1 to 4.6 .
# Partically we can see that there are too many app from size range 0 to 50,000 and app rating from 3.3 to 5.0 .

# %%
sns.pairplot(df,vars=['Reviews','Size','Rating','Price'])

# %%
plt.figure(figsize=(10,7))
sns.barplot(x='Content Rating',y='Rating',data=df,hue='Content Rating',palette='husl',estimator=np.median)

# %% [raw]
# Here the right metric used for the bar plot is mode.

# %%
plt.figure(figsize=(10,7))
sns.boxplot(x='Content Rating',y='Rating',data=df,hue='Content Rating',palette='husl')

# %%
df['Size'].max()
# Out:
# 100000.0

# %%
#5 Buckets (205 record of each) based on size is created.
bins = [0,20000,40000,60000,80000,100000]
labels=[1,2,3,4,5]
df['Size Bucket']=pd.cut(df['Size'],bins,labels=labels)
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10834                                      FR Calculator               FAMILY
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
#Content Rating vs Size Bucket
plt.figure(figsize=(10,7))
sns.barplot(x='Size Bucket',y='Content Rating',data=df,hue='Content Rating',palette='husl')

# %%
group = df.groupby(by=['Content Rating','Size Bucket'])['Rating'].quantile(.2).unstack()
group
# Out:
# Size Bucket        1    2     3    4     5
# Content Rating
# Everyone        3.80  4.0  3.90  4.0  4.04
# Everyone 10+    4.02  4.0  4.08  4.0  4.10
# Mature 17+      3.50  4.0  4.10  4.0  4.00
# Teen            3.90  3.9  4.00  4.0  4.00

# %%
sns.heatmap(group,annot=True,cmap='Greens', fmt=".1f",annot_kws={'size':16})
